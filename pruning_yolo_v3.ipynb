# %%
from absl import app, flags, logging
from absl.flags import FLAGS

import tensorflow as tf
import numpy as np
import cv2
import time
from tensorflow.keras.callbacks import (
    ReduceLROnPlateau,
    EarlyStopping,
    ModelCheckpoint,
    TensorBoard
)
from yolov3_tf2.models import (
    YoloV3, YoloV3Tiny, YoloLoss,
    yolo_anchors, yolo_anchor_masks,
    yolo_tiny_anchors, yolo_tiny_anchor_masks
)
from yolov3_tf2.utils import freeze_all
import yolov3_tf2.dataset as dataset

flags.DEFINE_string('dataset', '', 'path to dataset')
flags.DEFINE_string('val_dataset', '', 'path to validation dataset')
flags.DEFINE_boolean('tiny', False, 'yolov3 or yolov3-tiny')
flags.DEFINE_string('weights', './checkpoints/yolov3.tf',
                    'path to weights file')
flags.DEFINE_string('classes', './data/coco.names', 'path to classes file')
flags.DEFINE_enum('mode', 'fit', ['fit', 'eager_fit', 'eager_tf'],
                  'fit: model.fit, '
                  'eager_fit: model.fit(run_eagerly=True), '
                  'eager_tf: custom GradientTape')
flags.DEFINE_enum('transfer', 'none',
                  ['none', 'darknet', 'no_output', 'frozen', 'fine_tune'],
                  'none: Training from scratch, '
                  'darknet: Transfer darknet, '
                  'no_output: Transfer all but output, '
                  'frozen: Transfer and freeze all, '
                  'fine_tune: Transfer all and freeze darknet only')
flags.DEFINE_integer('size', 416, 'image size')
flags.DEFINE_integer('epochs', 2, 'number of epochs')
flags.DEFINE_integer('batch_size', 8, 'batch size')
flags.DEFINE_float('learning_rate', 1e-3, 'learning rate')
flags.DEFINE_integer('num_classes', 80, 'number of classes in the model')
flags.DEFINE_integer('weights_num_classes', None, 'specify num class for `weights` file if different, '
                     'useful in transfer learning with different number of classes')
flags.DEFINE_boolean('multi_gpu', False, 'Use if wishing to train with more than 1 GPU.')


def setup_model():
    if FLAGS.tiny:
        model = YoloV3Tiny(FLAGS.size, training=True,
                           classes=FLAGS.num_classes)
        anchors = yolo_tiny_anchors
        anchor_masks = yolo_tiny_anchor_masks
    else:
        model = YoloV3(FLAGS.size, training=True, classes=FLAGS.num_classes)
        anchors = yolo_anchors
        anchor_masks = yolo_anchor_masks

    # Configure the model for transfer learning
    if FLAGS.transfer == 'none':
        pass  # Nothing to do
    elif FLAGS.transfer in ['darknet', 'no_output']:
        # Darknet transfer is a special case that works
        # with incompatible number of classes
        # reset top layers
        if FLAGS.tiny:
            model_pretrained = YoloV3Tiny(
                FLAGS.size, training=True, classes=FLAGS.weights_num_classes or FLAGS.num_classes)
        else:
            model_pretrained = YoloV3(
                FLAGS.size, training=True, classes=FLAGS.weights_num_classes or FLAGS.num_classes)
        model_pretrained.load_weights(FLAGS.weights)

        if FLAGS.transfer == 'darknet':
            model.get_layer('yolo_darknet').set_weights(
                model_pretrained.get_layer('yolo_darknet').get_weights())
            freeze_all(model.get_layer('yolo_darknet'))
        elif FLAGS.transfer == 'no_output':
            for l in model.layers:
                if not l.name.startswith('yolo_output'):
                    l.set_weights(model_pretrained.get_layer(
                        l.name).get_weights())
                    freeze_all(l)
    else:
        # All other transfer require matching classes
        model.load_weights(FLAGS.weights)
        if FLAGS.transfer == 'fine_tune':
            # freeze darknet and fine tune other layers
            darknet = model.get_layer('yolo_darknet')
            freeze_all(darknet)
        elif FLAGS.transfer == 'frozen':
            # freeze everything
            freeze_all(model)

    optimizer = tf.keras.optimizers.Adam(lr=FLAGS.learning_rate)
    loss = [YoloLoss(anchors[mask], classes=FLAGS.num_classes)
            for mask in anchor_masks]

    model.compile(optimizer=optimizer, loss=loss,
                  run_eagerly=(FLAGS.mode == 'eager_fit'))

    return model, optimizer, loss, anchors, anchor_masks

# %%
setup_model()
# Out:
# ---------------------------------------------------------------------------
# UnparsedFlagAccessError                   Traceback (most recent call last)
# <ipython-input-2-f08408178a7b> in <module>
# ----> 1 setup_model()
#
# <ipython-input-1-60ac49955597> in setup_model()
#      48
#      49 def setup_model():
# ---> 50     if FLAGS.tiny:
#      51         model = YoloV3Tiny(FLAGS.size, training=True,
#      52                            classes=FLAGS.num_classes)
#
# ~/virtualenv/mltf250_1/lib/python3.6/site-packages/absl/flags/_flagvalues.py in __getattr__(self, name)
#     497         # get too much noise.
#     498         logging.error(error_message)
# --> 499       raise _exceptions.UnparsedFlagAccessError(error_message)
#     500
#     501   def __setattr__(self, name, value):
#
# UnparsedFlagAccessError: Trying to access flag --tiny before flags were parsed.

# %%
def setup_model2():
    model = YoloV3(416, training=True,
                           classes=80)
    anchors = yolo_tiny_anchors
    anchor_masks = yolo_tiny_anchor_masks
    model.load_weights('./checkpoints/yolov3.tf')
    darknet = model.get_layer('yolo_darknet')
    freeze_all(darknet)
    model.summary()
    return model

setup_model2()
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-8
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-9
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-10
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-11
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-28
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-16
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-17
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-31
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-32
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-33
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-18
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-19
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-36
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-20
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-21
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-39
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-22
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-23
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-42
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-43
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-24
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-25
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-46
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-26
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-27
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-49
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-50
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-28
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-29
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-53
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-30
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-31
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-56
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-57
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-32
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-33
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-60
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-34
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-35
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-63
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-64
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-36
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-37
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-67
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-38
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-39
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-70
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-71
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-40
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-41
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-74
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-42
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-43
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-77
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-78
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-44
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-45
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-81
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-46
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-47
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-84
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-85
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-48
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-49
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-88
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-50
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-51
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-91
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-92
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-93
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-52
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-53
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-96
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-54
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-55
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-99
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-56
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-57
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-102
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-103
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-58
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-59
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-106
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-60
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-61
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-109
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-110
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-62
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-63
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-113
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-64
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-65
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-116
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-117
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-66
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-67
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-120
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-68
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-69
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-123
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-124
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-70
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-71
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-127
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-72
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-73
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-130
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-131
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-74
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-75
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-134
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-76
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-77
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-137
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-138
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-78
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-79
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-141
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-80
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-81
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-144
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-145
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-82
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-83
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-148
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-84
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-85
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-151
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-152
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-153
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-86
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-87
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-156
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-88
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-89
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-159
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-90
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-91
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-162
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-163
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-92
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-93
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-166
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-94
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-95
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-169
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-170
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-96
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-97
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-173
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-98
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-99
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-176
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-177
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-100
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-101
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-180
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-102
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-103
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-183
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer-184
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-3
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer-6
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-4
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-5
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer-9
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-6
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-7
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer-12
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-8
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-9
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer-15
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-3
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer-9
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-4
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-5
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer-12
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-6
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-7
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer-15
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-8
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-9
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer-18
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-10
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-11
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer-21
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer-6
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-3
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer-9
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-4
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-5
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer-12
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-6
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-7
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer-15
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-8
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-9
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer-18
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-10
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-11
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer-21
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5.layer-0
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5.layer_with_weights-0
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5.layer_with_weights-1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5.layer-3
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5.layer_with_weights-2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5.layer-5
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6.layer-0
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6.layer_with_weights-0
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6.layer_with_weights-1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6.layer-3
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6.layer_with_weights-2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6.layer-5
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-14.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-15.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-15.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-15.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-15.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-15.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-16.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-17.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-17.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-17.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-17.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-17.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-18.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-19.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-19.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-19.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-19.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-19.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-20.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-21.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-21.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-21.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-21.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-21.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-22.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-23.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-23.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-23.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-23.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-23.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-24.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-25.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-25.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-25.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-25.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-25.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-26.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-27.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-27.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-27.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-27.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-27.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-28.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-29.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-29.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-29.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-29.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-29.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-30.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-31.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-31.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-31.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-31.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-31.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-32.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-33.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-33.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-33.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-33.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-33.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-34.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-35.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-35.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-35.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-35.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-35.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-36.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-37.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-37.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-37.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-37.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-37.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-38.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-39.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-39.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-39.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-39.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-39.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-40.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-41.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-41.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-41.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-41.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-41.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-42.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-43.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-43.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-43.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-43.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-43.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-44.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-45.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-45.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-45.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-45.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-45.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-46.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-47.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-47.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-47.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-47.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-47.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-48.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-49.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-49.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-49.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-49.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-49.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-50.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-51.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-51.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-51.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-51.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-51.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-52.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-53.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-53.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-53.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-53.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-53.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-54.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-55.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-55.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-55.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-55.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-55.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-56.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-57.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-57.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-57.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-57.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-57.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-58.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-59.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-59.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-59.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-59.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-59.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-60.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-61.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-61.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-61.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-61.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-61.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-62.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-63.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-63.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-63.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-63.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-63.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-64.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-65.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-65.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-65.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-65.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-65.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-66.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-67.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-67.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-67.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-67.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-67.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-68.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-69.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-69.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-69.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-69.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-69.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-70.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-71.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-71.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-71.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-71.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-71.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-72.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-73.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-73.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-73.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-73.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-73.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-74.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-75.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-75.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-75.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-75.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-75.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-76.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-77.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-77.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-77.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-77.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-77.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-78.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-79.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-79.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-79.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-79.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-79.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-80.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-81.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-81.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-81.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-81.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-81.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-82.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-83.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-83.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-83.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-83.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-83.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-84.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-85.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-85.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-85.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-85.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-85.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-86.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-87.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-87.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-87.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-87.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-87.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-88.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-89.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-89.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-89.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-89.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-89.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-90.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-91.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-91.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-91.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-91.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-91.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-92.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-93.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-93.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-93.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-93.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-93.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-94.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-95.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-95.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-95.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-95.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-95.moving_variance
# ...
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-97.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-97.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-97.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-98.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-99.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-99.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-99.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-99.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-99.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-100.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-101.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-101.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-101.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-101.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-101.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-102.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-103.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-103.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-103.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-103.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.layer_with_weights-103.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-3.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-3.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-3.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-3.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-3.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-5.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-5.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-5.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-5.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-5.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-6.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-7.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-7.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-7.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-7.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-7.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-8.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-9.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-9.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-9.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-9.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.layer_with_weights-9.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-3.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-3.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-3.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-3.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-3.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-5.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-5.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-5.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-5.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-5.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-6.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-7.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-7.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-7.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-7.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-7.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-8.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-9.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-9.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-9.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-9.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-9.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-10.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-11.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-11.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-11.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-11.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.layer_with_weights-11.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-3.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-3.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-3.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-3.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-3.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-5.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-5.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-5.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-5.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-5.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-6.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-7.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-7.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-7.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-7.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-7.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-8.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-9.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-9.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-9.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-9.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-9.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-10.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-11.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-11.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-11.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-11.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.layer_with_weights-11.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5.layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5.layer_with_weights-1.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5.layer_with_weights-1.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5.layer_with_weights-1.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5.layer_with_weights-1.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5.layer_with_weights-1.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5.layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5.layer_with_weights-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6.layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6.layer_with_weights-1.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6.layer_with_weights-1.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6.layer_with_weights-1.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6.layer_with_weights-1.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6.layer_with_weights-1.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6.layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6.layer_with_weights-2.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# Model: "yolov3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# yolo_darknet (Functional)       ((None, None, None,  40620640    input[0][0]
# __________________________________________________________________________________________________
# yolo_conv_0 (Functional)        (None, 13, 13, 512)  11024384    yolo_darknet[0][2]
# __________________________________________________________________________________________________
# yolo_conv_1 (Functional)        (None, 26, 26, 256)  2957312     yolo_conv_0[0][0]
#                                                                  yolo_darknet[0][1]
# __________________________________________________________________________________________________
# yolo_conv_2 (Functional)        (None, 52, 52, 128)  741376      yolo_conv_1[0][0]
#                                                                  yolo_darknet[0][0]
# __________________________________________________________________________________________________
# yolo_output_0 (Functional)      (None, None, None, 3 4984063     yolo_conv_0[0][0]
# __________________________________________________________________________________________________
# yolo_output_1 (Functional)      (None, None, None, 3 1312511     yolo_conv_1[0][0]
# __________________________________________________________________________________________________
# yolo_output_2 (Functional)      (None, None, None, 3 361471      yolo_conv_2[0][0]
# ==================================================================================================
# Total params: 62,001,757
# Trainable params: 21,364,221
# Non-trainable params: 40,637,536
# __________________________________________________________________________________________________

# %%
model = setup_model2()
# Out:
# Model: "yolov3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# yolo_darknet (Functional)       ((None, None, None,  40620640    input[0][0]
# __________________________________________________________________________________________________
# yolo_conv_0 (Functional)        (None, 13, 13, 512)  11024384    yolo_darknet[0][2]
# __________________________________________________________________________________________________
# yolo_conv_1 (Functional)        (None, 26, 26, 256)  2957312     yolo_conv_0[0][0]
#                                                                  yolo_darknet[0][1]
# __________________________________________________________________________________________________
# yolo_conv_2 (Functional)        (None, 52, 52, 128)  741376      yolo_conv_1[0][0]
#                                                                  yolo_darknet[0][0]
# __________________________________________________________________________________________________
# yolo_output_0 (Functional)      (None, None, None, 3 4984063     yolo_conv_0[0][0]
# __________________________________________________________________________________________________
# yolo_output_1 (Functional)      (None, None, None, 3 1312511     yolo_conv_1[0][0]
# __________________________________________________________________________________________________
# yolo_output_2 (Functional)      (None, None, None, 3 361471      yolo_conv_2[0][0]
# ==================================================================================================
# Total params: 62,001,757
# Trainable params: 21,364,221
# Non-trainable params: 40,637,536
# __________________________________________________________________________________________________

# %%
model.summary()
# Out:
# Model: "yolov3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# yolo_darknet (Functional)       ((None, None, None,  40620640    input[0][0]
# __________________________________________________________________________________________________
# yolo_conv_0 (Functional)        (None, 13, 13, 512)  11024384    yolo_darknet[0][2]
# __________________________________________________________________________________________________
# yolo_conv_1 (Functional)        (None, 26, 26, 256)  2957312     yolo_conv_0[0][0]
#                                                                  yolo_darknet[0][1]
# __________________________________________________________________________________________________
# yolo_conv_2 (Functional)        (None, 52, 52, 128)  741376      yolo_conv_1[0][0]
#                                                                  yolo_darknet[0][0]
# __________________________________________________________________________________________________
# yolo_output_0 (Functional)      (None, None, None, 3 4984063     yolo_conv_0[0][0]
# __________________________________________________________________________________________________
# yolo_output_1 (Functional)      (None, None, None, 3 1312511     yolo_conv_1[0][0]
# __________________________________________________________________________________________________
# yolo_output_2 (Functional)      (None, None, None, 3 361471      yolo_conv_2[0][0]
# ==================================================================================================
# Total params: 62,001,757
# Trainable params: 21,364,221
# Non-trainable params: 40,637,536
# __________________________________________________________________________________________________

# %%
import tensorflow_model_optimization as tfmot 
from tensorflow_model_optimization.python.core.sparsity.keras import pruning_schedule as pruning_sched

prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude

# Compute end step to finish pruning after 2 epochs.
batch_size = 8
epochs = 2
validation_split = 0.1 # 10% of training set will be used for validation set. 

num_images = 40000
end_step = 800


#'''
#Defining pruning parameters

pruning_params = {
      'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.50,
                                                               final_sparsity=0.80,
                                                               begin_step=0,
                                                               end_step=1000)
}

#'''

model_for_pruning = tfmot.sparsity.keras.prune_low_magnitude(model, **pruning_params)

#model_for_pruning.compile(optimizer=adam, loss=ssd_loss.compute_loss)
model_for_pruning.compile()

#model_for_pruning.compile(optimizer=adam, loss='sparse_categorical_crossentropy')

model_for_pruning.summary()
#'''
# Out:
# Model: "yolov3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# yolo_darknet (Functional)       ((None, None, None,  81170092    input[0][0]
# __________________________________________________________________________________________________
# yolo_conv_0 (Functional)        (None, 13, 13, 512)  22034452    yolo_darknet[0][2]
# __________________________________________________________________________________________________
# yolo_conv_1 (Functional)        (None, 26, 26, 256)  5906458     yolo_conv_0[0][0]
#                                                                  yolo_darknet[0][1]
# __________________________________________________________________________________________________
# yolo_conv_2 (Functional)        (None, 52, 52, 128)  1478682     yolo_conv_1[0][0]
#                                                                  yolo_darknet[0][0]
# __________________________________________________________________________________________________
# yolo_output_0 (Functional)      (None, None, None, 3 9963782     yolo_conv_0[0][0]
# __________________________________________________________________________________________________
# yolo_output_1 (Functional)      (None, None, None, 3 2622726     yolo_conv_1[0][0]
# __________________________________________________________________________________________________
# yolo_output_2 (Functional)      (None, None, None, 3 721670      yolo_conv_2[0][0]
# ==================================================================================================
# Total params: 123,897,862
# Trainable params: 21,364,221
# Non-trainable params: 102,533,641
# __________________________________________________________________________________________________

# %%
if __name__ == '__setup_model__':
    try:
        app.run(setup_model)
    except SystemExit:
        pass
